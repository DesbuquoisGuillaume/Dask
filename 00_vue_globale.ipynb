# %%
# %run Formation_Dask\preparations_donnees.py
# Out:
# ERROR:root:File `'Formation_Dask\\preparations_donnees.py'` not found.

# %%
# !ls
# Out:
# 'ls' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.
